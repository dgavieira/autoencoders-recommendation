# %% [markdown]
# <a href="https://colab.research.google.com/github/dgavieira/autoencoders-recommendation/blob/main/trabalho_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

movies_url = "/content/drive/MyDrive/Mestrado/PGENE613-Topicos-Avancados-Aprendizado-Maquina-Otimizacao/trabalho-2/Movies/movies.csv"
ratings_url = "/content/drive/MyDrive/Mestrado/PGENE613-Topicos-Avancados-Aprendizado-Maquina-Otimizacao/trabalho-2/Movies/ratings.csv"

movies = pd.read_csv(movies_url)
ratings = pd.read_csv(ratings_url)

# Exibindo as 5 primeiras linhas de cada DataFrame
print("Filmes:")
print(movies.head())
print("\nAvaliações:")
print(ratings.head())

# Preparar a matriz de ratings (usuários x filmes)
n_users = ratings['userId'].nunique()
n_movies = len(movies)  # Usar o número total de filmes no arquivo movies.csv

# Criando uma matriz de usuários e filmes, preenchendo com as avaliações
Y = np.zeros((n_users, n_movies))

# Mapeamento de IDs de filmes e usuários para índices consecutivos
movie_indices = {movie_id: idx for idx, movie_id in enumerate(movies['movieId'])}
user_indices = {user_id: idx for idx, user_id in enumerate(ratings['userId'].unique())}

# Preencher a matriz Y com as avaliações
for row in ratings.itertuples():
    user_idx = user_indices[row.userId]
    if row.movieId in movie_indices:  # Certificar que o filme existe na lista de filmes
        movie_idx = movie_indices[row.movieId]
        Y[user_idx, movie_idx] = row.rating

# Exibir dimensões da matriz de ratings Y
print(f'\nDimensões da matriz de avaliações Y: {Y.shape}')
# Out:
# Filmes:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#
# Avaliações:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
#
# Dimensões da matriz de avaliações Y: (610, 9742)

# %%
# Função para calcular o erro médio quadrático
def mse(Y, R):
    return np.mean((Y - R) ** 2)

# Inicializar aleatoriamente as matrizes W e V
def initialize_factors(n_users, n_movies, k):
    W = np.random.rand(n_users, k)  # Fatores de usuário
    V = np.random.rand(n_movies, k)  # Fatores de filme
    return W, V

# %%
# Treinamento com Fatoração de Matriz
def train_matrix_factorization(Y, k, alpha, lambda_, max_iters, threshold):
    n_users, n_movies = Y.shape
    W, V = initialize_factors(n_users, n_movies, k)

    # Conjunto S = {(i,j); (entrada i ≠ 0, saída j ≠ 0)}
    S = [(i, j) for i in range(n_users) for j in range(n_movies) if Y[i, j] > 0]

    for iteration in range(max_iters):
        np.random.shuffle(S)  # Misturar aleatoriamente os dados

        for i, j in S:
            # Cálculo do erro eij
            eij = Y[i, j] - np.dot(W[i, :], V[j, :])

            # Atualizar W e V
            W[i, :] = W[i, :] * (1 - 2 * alpha * lambda_) + 2 * alpha * eij * V[j, :]
            V[j, :] = V[j, :] * (1 - 2 * alpha * lambda_) + 2 * alpha * eij * W[i, :]

        # Verificar condição de convergência
        R = np.dot(W, V.T)
        current_mse = mse(Y, R)
        print(f'Iteração {iteration+1}: MSE = {current_mse}')

        if current_mse < threshold:
            print(f'Convergência alcançada com MSE = {current_mse}')
            break

    return W, V, current_mse

# %%
# Parâmetros do modelo
alpha = 0.005  # Taxa de aprendizado
lambda_ = 0.0005  # Fator de regularização
k = 50  # Número de neurônios escondidos
max_iters = 100  # Número máximo de iterações
threshold = 0.1  # Condição de convergência (MSE)

# Exemplo: Simulação dos dados de entrada Y (substituir pela matriz real)
# Aqui, Y seria a matriz de avaliações de filmes pelos usuários
n_users, n_movies = 610, 9742  # Exemplo: número de usuários e filmes
Y = np.random.rand(n_users, n_movies)  # Simulação: substitua pelos dados reais

# Treinamento do modelo
W, V, final_mse = train_matrix_factorization(Y, k, alpha, lambda_, max_iters, threshold)

# Matriz de predições final
R = np.dot(W, V.T)

# Exibindo o erro final e a matriz de predições
print(f"Erro final (MSE): {final_mse}")
print(f"Matriz de predições (R):\n {R}")
# Out:
# Iteração 1: MSE = 0.09152372839494378
# Convergência alcançada com MSE = 0.09152372839494378
# Erro final (MSE): 0.09152372839494378
# Matriz de predições (R):
#  [[0.43887285 0.47810525 0.45458883 ... 0.5436856  0.33054036 0.55024043]
#  [0.43265002 0.58795245 0.50758611 ... 0.47446109 0.41389703 0.53335908]
#  [0.54240172 0.53896848 0.56663684 ... 0.61627154 0.51553623 0.55893564]
#  ...
#  [0.48103732 0.4513035  0.44068525 ... 0.38328378 0.38827846 0.51688026]
#  [0.34702749 0.48351116 0.41943084 ... 0.44250675 0.36676215 0.40111707]
#  [0.30904719 0.53421814 0.4022599  ... 0.4247141  0.44727329 0.43874286]]

# %%
# Importar as bibliotecas necessárias
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Carregar os dados
movies_url = "/content/drive/MyDrive/Mestrado/PGENE613-Topicos-Avancados-Aprendizado-Maquina-Otimizacao/trabalho-2/Movies/movies.csv"
ratings_url = "/content/drive/MyDrive/Mestrado/PGENE613-Topicos-Avancados-Aprendizado-Maquina-Otimizacao/trabalho-2/Movies/ratings.csv"

movies = pd.read_csv(movies_url)
ratings = pd.read_csv(ratings_url)

# Preparar a matriz de ratings (usuários x filmes)
n_users = ratings['userId'].nunique()
n_movies = len(movies)

# Criar a matriz de usuários e filmes, preenchendo com as avaliações
Y = np.zeros((n_users, n_movies))

# Mapeamento de IDs de filmes e usuários para índices consecutivos
movie_indices = {movie_id: idx for idx, movie_id in enumerate(movies['movieId'])}
user_indices = {user_id: idx for idx, user_id in enumerate(ratings['userId'].unique())}

# Preencher a matriz Y com as avaliações
for row in ratings.itertuples():
    user_idx = user_indices[row.userId]
    if row.movieId in movie_indices:
        movie_idx = movie_indices[row.movieId]
        Y[user_idx, movie_idx] = row.rating

# Dividir os dados em treino e teste
Y_train, Y_test = train_test_split(Y, test_size=0.2, random_state=42)

# Parâmetros do modelo
k_values = [50, 75, 100]  # Três valores de k sugeridos
alpha = 0.005  # Taxa de aprendizado
lmbda = 0.0005  # Fator de regularização (10x menor que a taxa de aprendizado)

# Definir e treinar o autoencoder
def train_autoencoder(Y_train, k, alpha, lmbda, epochs=100, batch_size=32):
    input_dim = Y_train.shape[1]
    # Definir o modelo de autoencoder
    input_layer = tf.keras.layers.Input(shape=(input_dim,))
    hidden_layer = tf.keras.layers.Dense(k, activation='relu',
                                         kernel_regularizer=tf.keras.regularizers.l2(lmbda))(input_layer)
    output_layer = tf.keras.layers.Dense(input_dim, activation='linear')(hidden_layer)

    model = tf.keras.Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=alpha), loss='mse')

    # Treinar o modelo
    model.fit(Y_train, Y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1, verbose=1)

    return model

# Treinando o modelo com k = 75 como exemplo
k = 75
autoencoder = train_autoencoder(Y_train, k, alpha, lmbda)

# Fazer previsões para os dados de teste
Y_pred = autoencoder.predict(Y)

# Gerar recomendações para usuários específicos
user_ids = [40, 92, 123, 245, 312, 460, 514, 590]

def get_recommendations(user_id, Y_pred, Y, movie_indices, movies, n_recommendations=5):
    user_idx = user_indices[user_id]

    # Obter as previsões de ratings do usuário
    user_ratings_pred = Y_pred[user_idx]

    # Remover os filmes já avaliados
    already_rated_indices = np.where(Y[user_idx] > 0)[0]
    user_ratings_pred[already_rated_indices] = -1  # Definir como -1 para ignorar

    # Selecionar os melhores filmes recomendados
    top_movie_indices = np.argsort(user_ratings_pred)[-n_recommendations:][::-1]
    top_movies = [movies.iloc[idx]['title'] for idx in top_movie_indices]

    return top_movies

# Gerar as recomendações e calcular o erro MSE para os usuários
recommendations = []
mse_values = []

for user_id in user_ids:
    top_movies = get_recommendations(user_id, Y_pred, Y, movie_indices, movies)
    recommendations.append(top_movies)

    # Calcular o MSE para os filmes que o usuário já avaliou
    user_idx = user_indices[user_id]
    user_ratings_true = Y[user_idx][Y[user_idx] > 0]  # Ratings reais
    user_ratings_pred = Y_pred[user_idx][Y[user_idx] > 0]  # Ratings preditos
    mse = mean_squared_error(user_ratings_true, user_ratings_pred)
    mse_values.append(mse)

# Criar a tabela final
user_ids_str = [str(uid) for uid in user_ids]
columns = ['Filme 1', 'Filme 2', 'Filme 3', 'Filme 4', 'Filme 5', 'MSE']

df_recommendations = pd.DataFrame(
    data=[rec + [mse] for rec, mse in zip(recommendations, mse_values)],
    index=user_ids_str,
    columns=columns
)

# Exibir a tabela final de recomendações
print(df_recommendations)
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - loss: 0.2227 - val_loss: 0.2088
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1847 - val_loss: 0.2253
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1855 - val_loss: 0.2249
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1941 - val_loss: 0.2264
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1799 - val_loss: 0.2162
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1808 - val_loss: 0.2261
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1796 - val_loss: 0.2132
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1728 - val_loss: 0.2123
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1979 - val_loss: 0.2202
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1916 - val_loss: 0.2328
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2161 - val_loss: 0.2560
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2408 - val_loss: 0.2644
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2133 - val_loss: 0.2516
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2092 - val_loss: 0.2362
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2099 - val_loss: 0.2332
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2116 - val_loss: 0.2267
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1845 - val_loss: 0.2158
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2013 - val_loss: 0.2388
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1873 - val_loss: 0.2206
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1722 - val_loss: 0.2166
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1791 - val_loss: 0.2089
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1850 - val_loss: 0.2129
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1727 - val_loss: 0.2153
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1650 - val_loss: 0.2021
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1733 - val_loss: 0.2099
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2032 - val_loss: 0.2165
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1808 - val_loss: 0.2111
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1783 - val_loss: 0.2165
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1693 - val_loss: 0.2224
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1978 - val_loss: 0.2241
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1914 - val_loss: 0.2233
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1733 - val_loss: 0.2170
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1747 - val_loss: 0.2140
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1646 - val_loss: 0.2106
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1712 - val_loss: 0.2180
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1579 - val_loss: 0.2074
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1716 - val_loss: 0.2054
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1752 - val_loss: 0.2120
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1523 - val_loss: 0.2011
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1716 - val_loss: 0.2060
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1771 - val_loss: 0.2042
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1666 - val_loss: 0.2040
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1722 - val_loss: 0.2085
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1803 - val_loss: 0.2050
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1660 - val_loss: 0.1971
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1630 - val_loss: 0.1981
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1666 - val_loss: 0.2005
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1683 - val_loss: 0.2073
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1624 - val_loss: 0.2021
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1588 - val_loss: 0.2027
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1465 - val_loss: 0.2134
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2017 - val_loss: 0.2141
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1658 - val_loss: 0.2140
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1842 - val_loss: 0.2053
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1789 - val_loss: 0.2027
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1501 - val_loss: 0.2035
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1597 - val_loss: 0.2063
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1632 - val_loss: 0.1978
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1656 - val_loss: 0.2004
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1505 - val_loss: 0.1965
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1679 - val_loss: 0.1983
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1548 - val_loss: 0.2104
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1664 - val_loss: 0.1967
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1633 - val_loss: 0.2031
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1547 - val_loss: 0.1938
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1598 - val_loss: 0.2068
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1601 - val_loss: 0.2020
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1618 - val_loss: 0.1977
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1533 - val_loss: 0.1988
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1574 - val_loss: 0.1959
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1649 - val_loss: 0.1943
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1640 - val_loss: 0.2030
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1473 - val_loss: 0.1945
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1546 - val_loss: 0.1985
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1620 - val_loss: 0.2046
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1473 - val_loss: 0.1962
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1627 - val_loss: 0.2035
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1442 - val_loss: 0.1966
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1601 - val_loss: 0.1952
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1515 - val_loss: 0.1996
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1628 - val_loss: 0.1941
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1595 - val_loss: 0.2006
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1713 - val_loss: 0.2040
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1545 - val_loss: 0.1991
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1610 - val_loss: 0.1968
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1550 - val_loss: 0.1990
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1550 - val_loss: 0.1945
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1660 - val_loss: 0.2036
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1628 - val_loss: 0.2038
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1553 - val_loss: 0.1973
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1788 - val_loss: 0.1941
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1798 - val_loss: 0.1940
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1551 - val_loss: 0.1962
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1603 - val_loss: 0.1944
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1609 - val_loss: 0.2019
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1544 - val_loss: 0.1921
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1538 - val_loss: 0.1948
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1720 - val_loss: 0.1951
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1530 - val_loss: 0.1935
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1555 - val_loss: 0.1899
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#                               Filme 1                           Filme 2  \
# 40                Forrest Gump (1994)              Jurassic Park (1993)
# 92   Shawshank Redemption, The (1994)                Matrix, The (1999)
# 123               Forrest Gump (1994)           Dark Knight, The (2008)
# 245  Shawshank Redemption, The (1994)                Matrix, The (1999)
# 312               Pulp Fiction (1994)  Silence of the Lambs, The (1991)
# 460           Dark Knight, The (2008)               Pulp Fiction (1994)
# 514  Shawshank Redemption, The (1994)             Godfather, The (1972)
# 590           Truman Show, The (1998)          Good Will Hunting (1997)
#
#                                                Filme 3  \
# 40                                 Crimson Tide (1995)
# 92                                 Forrest Gump (1994)
# 123                            Schindler's List (1993)
# 245                                Forrest Gump (1994)
# 312  Raiders of the Lost Ark (Indiana Jones and the...
# 460          Star Wars: Episode IV - A New Hope (1977)
# 514                            Schindler's List (1993)
# 590                           Full Metal Jacket (1987)
#
#                                                Filme 4  \
# 40                     Clear and Present Danger (1994)
# 92                                 Pulp Fiction (1994)
# 123                              Godfather, The (1972)
# 245                                Pulp Fiction (1994)
# 312                             American Beauty (1999)
# 460                   Silence of the Lambs, The (1991)
# 514                                   Gladiator (2000)
# 590  Léon: The Professional (a.k.a. The Professiona...
#
#                               Filme 5        MSE
# 40                       Speed (1994)  23.796117
# 92   Silence of the Lambs, The (1991)  24.781250
# 123                  Gladiator (2000)  25.491071
# 245  Silence of the Lambs, The (1991)  14.571429
# 312             Godfather, The (1972)  22.914798
# 460             Godfather, The (1972)  27.472561
# 514        Usual Suspects, The (1995)  19.485516
# 590             Monsters, Inc. (2001)  19.667582

# %%
# Importar as bibliotecas necessárias
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import mean_squared_error

# Carregar os dados
# Carregar os dados
movies_url = "/content/drive/MyDrive/Mestrado/PGENE613-Topicos-Avancados-Aprendizado-Maquina-Otimizacao/trabalho-2/Movies/movies.csv"
ratings_url = "/content/drive/MyDrive/Mestrado/PGENE613-Topicos-Avancados-Aprendizado-Maquina-Otimizacao/trabalho-2/Movies/ratings.csv"

movies = pd.read_csv(movies_url)
ratings = pd.read_csv(ratings_url)

# Preparar a matriz de ratings (usuários x filmes)
n_users = ratings['userId'].nunique()
n_movies = len(movies)

# Criar a matriz de usuários e filmes, preenchendo com as avaliações
Y = np.zeros((n_users, n_movies))

# Mapeamento de IDs de filmes e usuários para índices consecutivos
movie_indices = {movie_id: idx for idx, movie_id in enumerate(movies['movieId'])}
user_indices = {user_id: idx for idx, user_id in enumerate(ratings['userId'].unique())}

# Preencher a matriz Y com as avaliações
for row in ratings.itertuples():
    user_idx = user_indices[row.userId]
    if row.movieId in movie_indices:
        movie_idx = movie_indices[row.movieId]
        Y[user_idx, movie_idx] = row.rating

# Definir o autoencoder
def build_autoencoder(input_dim, k, alpha, lmbda):
    # Definir a arquitetura do autoencoder
    input_layer = tf.keras.layers.Input(shape=(input_dim,))
    hidden_layer = tf.keras.layers.Dense(k, activation='relu',
                                         kernel_initializer='random_uniform',
                                         bias_initializer='random_uniform',
                                         kernel_regularizer=tf.keras.regularizers.l2(lmbda))(input_layer)
    output_layer = tf.keras.layers.Dense(input_dim, activation='linear')(hidden_layer)

    model = tf.keras.Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=alpha), loss='mse')

    return model

# Definir parâmetros
alpha = 0.005  # Taxa de aprendizado
lmbda = 0.0005  # Fator de regularização (10x menor que alpha)
k_values = [50, 75, 100]  # Três valores de k (neurônios na camada escondida)
epochs = 100
batch_size = 32

# Dividir dados em treino e teste (opcional, mas aqui treinamos com todo o dataset)
Y_train = Y

# Função para treinar e testar o autoencoder com diferentes valores de k
def train_and_evaluate_autoencoder(Y_train, k_values, alpha, lmbda, mse_threshold=0.1):
    for k in k_values:
        print(f'Treinando com k = {k}...')
        model = build_autoencoder(input_dim=Y_train.shape[1], k=k, alpha=alpha, lmbda=lmbda)

        # Treinar o modelo
        model.fit(Y_train, Y_train, epochs=epochs, batch_size=batch_size, verbose=1, validation_split=0.1)

        # Fazer previsões
        Y_pred = model.predict(Y_train)

        # Calcular o erro médio quadrático global
        mse = mean_squared_error(Y_train[Y_train > 0], Y_pred[Y_train > 0])
        print(f'MSE com k={k}: {mse}')

        # Verificar se o MSE está abaixo do threshold e encerrar a simulação
        if mse < mse_threshold:
            print(f'MSE alcançado menor que {mse_threshold}, finalizando...')
            return Y_pred, mse

    return Y_pred, mse

# Treinar e avaliar o autoencoder com diferentes valores de k
Y_pred, final_mse = train_and_evaluate_autoencoder(Y_train, k_values, alpha, lmbda)

# Definir os usuários para os quais faremos recomendações
user_ids = [40, 92, 123, 245, 312, 460, 514, 590]

# Função para obter as recomendações
def get_recommendations(user_id, Y_pred, Y, movie_indices, movies, n_recommendations=5):
    user_idx = user_indices[user_id]

    # Obter as previsões de ratings do usuário
    user_ratings_pred = Y_pred[user_idx]

    # Remover os filmes já avaliados
    already_rated_indices = np.where(Y[user_idx] > 0)[0]
    user_ratings_pred[already_rated_indices] = -1  # Definir como -1 para ignorar

    # Selecionar os melhores filmes recomendados
    top_movie_indices = np.argsort(user_ratings_pred)[-n_recommendations:][::-1]
    top_movies = [movies.iloc[idx]['title'] for idx in top_movie_indices]

    return top_movies

# Gerar as recomendações e calcular o erro MSE para os usuários
recommendations = []
mse_values = []

for user_id in user_ids:
    top_movies = get_recommendations(user_id, Y_pred, Y, movie_indices, movies)
    recommendations.append(top_movies)

    # Calcular o MSE para os filmes que o usuário já avaliou
    user_idx = user_indices[user_id]
    user_ratings_true = Y[user_idx][Y[user_idx] > 0]  # Ratings reais
    user_ratings_pred = Y_pred[user_idx][Y[user_idx] > 0]  # Ratings preditos
    mse = mean_squared_error(user_ratings_true, user_ratings_pred)
    mse_values.append(mse)

# Criar a tabela final
user_ids_str = [str(uid) for uid in user_ids]
columns = ['Filme 1', 'Filme 2', 'Filme 3', 'Filme 4', 'Filme 5', 'MSE']

df_recommendations = pd.DataFrame(
    data=[rec + [mse] for rec, mse in zip(recommendations, mse_values)],
    index=user_ids_str,
    columns=columns
)

# Exibir a tabela final de recomendações
df_recommendations
# Out:
# Treinando com k = 50...
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.3034 - val_loss: 0.2815
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1915 - val_loss: 0.2872
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2147 - val_loss: 0.2794
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2157 - val_loss: 0.2730
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1805 - val_loss: 0.2741
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2252 - val_loss: 0.2946
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1980 - val_loss: 0.2881
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2338 - val_loss: 0.3110
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2150 - val_loss: 0.2828
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1911 - val_loss: 0.2816
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1978 - val_loss: 0.2832
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1885 - val_loss: 0.2744
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1872 - val_loss: 0.2852
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1949 - val_loss: 0.2848
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1998 - val_loss: 0.2816
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1918 - val_loss: 0.2715
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1786 - val_loss: 0.2682
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1783 - val_loss: 0.2641
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1678 - val_loss: 0.2627
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1600 - val_loss: 0.2748
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1927 - val_loss: 0.2642
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1787 - val_loss: 0.2643
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1713 - val_loss: 0.2677
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1760 - val_loss: 0.2604
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1684 - val_loss: 0.2579
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1684 - val_loss: 0.2584
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1621 - val_loss: 0.2844
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1999 - val_loss: 0.2830
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1849 - val_loss: 0.2745
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1830 - val_loss: 0.2745
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1803 - val_loss: 0.2642
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1673 - val_loss: 0.2622
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1744 - val_loss: 0.2590
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1862 - val_loss: 0.2579
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1704 - val_loss: 0.2585
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1697 - val_loss: 0.2649
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1679 - val_loss: 0.2710
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1806 - val_loss: 0.2733
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1662 - val_loss: 0.2701
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1608 - val_loss: 0.2700
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1716 - val_loss: 0.2666
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1588 - val_loss: 0.2576
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1761 - val_loss: 0.2613
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1862 - val_loss: 0.2813
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1731 - val_loss: 0.2741
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1780 - val_loss: 0.2692
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1684 - val_loss: 0.2692
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1632 - val_loss: 0.2654
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1716 - val_loss: 0.2684
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1905 - val_loss: 0.2679
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1727 - val_loss: 0.2720
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1679 - val_loss: 0.2893
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1768 - val_loss: 0.2836
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1827 - val_loss: 0.2668
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1784 - val_loss: 0.2713
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1653 - val_loss: 0.2657
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1720 - val_loss: 0.2629
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1792 - val_loss: 0.2667
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1718 - val_loss: 0.2589
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1634 - val_loss: 0.2621
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1556 - val_loss: 0.2628
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1715 - val_loss: 0.2599
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1684 - val_loss: 0.2614
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1750 - val_loss: 0.2584
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1681 - val_loss: 0.2606
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1852 - val_loss: 0.2708
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1675 - val_loss: 0.2626
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1791 - val_loss: 0.2693
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1888 - val_loss: 0.2636
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1686 - val_loss: 0.2648
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1717 - val_loss: 0.2599
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1629 - val_loss: 0.2597
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1653 - val_loss: 0.2579
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1720 - val_loss: 0.2616
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1750 - val_loss: 0.2726
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1722 - val_loss: 0.2851
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1758 - val_loss: 0.2667
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1784 - val_loss: 0.2638
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1596 - val_loss: 0.2624
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1887 - val_loss: 0.2664
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1691 - val_loss: 0.2604
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1663 - val_loss: 0.2591
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1681 - val_loss: 0.2787
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1619 - val_loss: 0.2600
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1606 - val_loss: 0.2597
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1818 - val_loss: 0.2659
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1728 - val_loss: 0.2732
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1716 - val_loss: 0.2949
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1940 - val_loss: 0.3040
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2193 - val_loss: 0.2923
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1840 - val_loss: 0.2857
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1809 - val_loss: 0.2743
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1875 - val_loss: 0.2724
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1733 - val_loss: 0.2766
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1766 - val_loss: 0.2741
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1776 - val_loss: 0.2699
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1882 - val_loss: 0.2681
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1834 - val_loss: 0.2647
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1793 - val_loss: 0.2659
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1762 - val_loss: 0.2654
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# MSE com k=50: 9.436206569219658
# Treinando com k = 75...
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 0.3420 - val_loss: 0.2998
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2072 - val_loss: 0.2890
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2044 - val_loss: 0.2960
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1982 - val_loss: 0.3072
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2147 - val_loss: 0.3065
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2202 - val_loss: 0.2999
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2047 - val_loss: 0.3007
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2005 - val_loss: 0.2926
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2138 - val_loss: 0.2921
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2444 - val_loss: 0.3098
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2184 - val_loss: 0.2859
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2112 - val_loss: 0.2776
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1948 - val_loss: 0.3256
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1986 - val_loss: 0.3191
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2115 - val_loss: 0.3241
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1985 - val_loss: 0.2836
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1973 - val_loss: 0.2790
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1926 - val_loss: 0.2786
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2492 - val_loss: 0.2726
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1904 - val_loss: 0.2735
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1708 - val_loss: 0.2646
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1877 - val_loss: 0.2710
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1950 - val_loss: 0.2714
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1810 - val_loss: 0.2796
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1842 - val_loss: 0.2760
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1742 - val_loss: 0.2757
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1612 - val_loss: 0.2661
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1678 - val_loss: 0.2569
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1662 - val_loss: 0.2561
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1625 - val_loss: 0.2549
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1696 - val_loss: 0.2593
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1881 - val_loss: 0.2774
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1671 - val_loss: 0.2711
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1822 - val_loss: 0.2628
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1562 - val_loss: 0.2638
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1630 - val_loss: 0.2785
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1706 - val_loss: 0.2973
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1973 - val_loss: 0.2956
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1838 - val_loss: 0.2691
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1780 - val_loss: 0.2651
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1616 - val_loss: 0.2707
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1773 - val_loss: 0.2635
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1674 - val_loss: 0.2625
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1883 - val_loss: 0.2703
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1840 - val_loss: 0.2691
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1663 - val_loss: 0.2755
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1783 - val_loss: 0.2685
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1747 - val_loss: 0.2645
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1798 - val_loss: 0.2621
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1807 - val_loss: 0.2612
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1582 - val_loss: 0.2580
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1802 - val_loss: 0.2598
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1632 - val_loss: 0.2785
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1797 - val_loss: 0.2756
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1804 - val_loss: 0.2829
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1794 - val_loss: 0.2894
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1978 - val_loss: 0.2692
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1672 - val_loss: 0.2664
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1875 - val_loss: 0.2725
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1821 - val_loss: 0.2620
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1694 - val_loss: 0.2676
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1980 - val_loss: 0.2824
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1677 - val_loss: 0.2719
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1884 - val_loss: 0.2777
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1625 - val_loss: 0.2677
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1658 - val_loss: 0.2858
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1899 - val_loss: 0.2663
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1622 - val_loss: 0.2643
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1795 - val_loss: 0.2617
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1566 - val_loss: 0.2623
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1804 - val_loss: 0.2889
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1746 - val_loss: 0.2831
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1766 - val_loss: 0.2718
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1688 - val_loss: 0.2610
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1741 - val_loss: 0.2685
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1721 - val_loss: 0.2654
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1888 - val_loss: 0.2655
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1676 - val_loss: 0.2647
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1864 - val_loss: 0.2569
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1804 - val_loss: 0.2576
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1708 - val_loss: 0.2590
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1810 - val_loss: 0.2704
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1851 - val_loss: 0.2699
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1751 - val_loss: 0.2622
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1779 - val_loss: 0.2590
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1635 - val_loss: 0.2570
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1804 - val_loss: 0.2686
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1676 - val_loss: 0.2577
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1670 - val_loss: 0.2618
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1523 - val_loss: 0.2644
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1680 - val_loss: 0.2785
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2114 - val_loss: 0.3082
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2155 - val_loss: 0.3242
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2106 - val_loss: 0.3302
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2140 - val_loss: 0.3276
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2211 - val_loss: 0.3239
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2102 - val_loss: 0.3213
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2122 - val_loss: 0.3192
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1948 - val_loss: 0.3180
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2026 - val_loss: 0.3169
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE com k=75: 11.092680610934998
# Treinando com k = 100...
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.3741 - val_loss: 0.2942
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2134 - val_loss: 0.3367
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2269 - val_loss: 0.3395
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2393 - val_loss: 0.3660
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2961 - val_loss: 0.3287
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2817 - val_loss: 0.3862
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3136 - val_loss: 0.3185
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2415 - val_loss: 0.3708
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2984 - val_loss: 0.3127
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2242 - val_loss: 0.3410
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2747 - val_loss: 0.3262
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2170 - val_loss: 0.3108
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2245 - val_loss: 0.2992
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2112 - val_loss: 0.3112
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1954 - val_loss: 0.2898
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1829 - val_loss: 0.2839
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2048 - val_loss: 0.3231
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1952 - val_loss: 0.2901
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1946 - val_loss: 0.2840
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1841 - val_loss: 0.2716
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1690 - val_loss: 0.2809
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1814 - val_loss: 0.2813
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1787 - val_loss: 0.2746
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1843 - val_loss: 0.3042
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2117 - val_loss: 0.3214
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3125 - val_loss: 0.2853
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2061 - val_loss: 0.2845
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1862 - val_loss: 0.2726
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1870 - val_loss: 0.2803
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1964 - val_loss: 0.2796
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1964 - val_loss: 0.3018
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1908 - val_loss: 0.2788
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1690 - val_loss: 0.2734
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2105 - val_loss: 0.2883
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1875 - val_loss: 0.3021
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1809 - val_loss: 0.2742
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1753 - val_loss: 0.2651
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1693 - val_loss: 0.2619
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1794 - val_loss: 0.2626
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1818 - val_loss: 0.2845
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1811 - val_loss: 0.2648
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1710 - val_loss: 0.2659
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1760 - val_loss: 0.2646
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1732 - val_loss: 0.2601
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1780 - val_loss: 0.2709
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1650 - val_loss: 0.2802
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1819 - val_loss: 0.2659
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1606 - val_loss: 0.2566
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1754 - val_loss: 0.2829
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1953 - val_loss: 0.2700
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1981 - val_loss: 0.2652
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1762 - val_loss: 0.2865
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1835 - val_loss: 0.2657
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1882 - val_loss: 0.2771
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1934 - val_loss: 0.2834
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1731 - val_loss: 0.2649
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1700 - val_loss: 0.2606
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1627 - val_loss: 0.2667
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1617 - val_loss: 0.2695
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1686 - val_loss: 0.2666
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1589 - val_loss: 0.2597
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1766 - val_loss: 0.2614
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1681 - val_loss: 0.2622
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1745 - val_loss: 0.2584
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1739 - val_loss: 0.2607
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1657 - val_loss: 0.2608
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1750 - val_loss: 0.3087
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1985 - val_loss: 0.3041
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1958 - val_loss: 0.3001
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1833 - val_loss: 0.2964
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1888 - val_loss: 0.2937
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1851 - val_loss: 0.2923
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1773 - val_loss: 0.2936
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1757 - val_loss: 0.2902
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1880 - val_loss: 0.2910
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1838 - val_loss: 0.2889
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1863 - val_loss: 0.2806
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1845 - val_loss: 0.2663
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1810 - val_loss: 0.2750
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2132 - val_loss: 0.2960
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1905 - val_loss: 0.3069
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2169 - val_loss: 0.3019
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2035 - val_loss: 0.2974
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2052 - val_loss: 0.2939
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2029 - val_loss: 0.2920
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1905 - val_loss: 0.2892
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1911 - val_loss: 0.2899
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1711 - val_loss: 0.2895
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1954 - val_loss: 0.2873
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1893 - val_loss: 0.2865
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1998 - val_loss: 0.2899
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1761 - val_loss: 0.2860
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1923 - val_loss: 0.2846
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1826 - val_loss: 0.2864
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1764 - val_loss: 0.2859
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1786 - val_loss: 0.2858
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1731 - val_loss: 0.2838
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1899 - val_loss: 0.2840
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1808 - val_loss: 0.2832
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1725 - val_loss: 0.2843
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# MSE com k=100: 9.993162527579008
#                               Filme 1                           Filme 2  \
# 40                 Matrix, The (1999)               Forrest Gump (1994)
# 92   Shawshank Redemption, The (1994)               Forrest Gump (1994)
# 123               Forrest Gump (1994)                 Braveheart (1995)
# 245  Shawshank Redemption, The (1994)               Forrest Gump (1994)
# 312  Shawshank Redemption, The (1994)               Pulp Fiction (1994)
# 460               Pulp Fiction (1994)  Silence of the Lambs, The (1991)
# 514  Shawshank Redemption, The (1994)             Godfather, The (1972)
# 590           Truman Show, The (1998)          Good Will Hunting (1997)
#
#                                        Filme 3  \
# 40   Star Wars: Episode IV - A New Hope (1977)
# 92                         Pulp Fiction (1994)
# 123                    Schindler's List (1993)
# 245                        Pulp Fiction (1994)
# 312                          Fight Club (1999)
# 460  Star Wars: Episode IV - A New Hope (1977)
# 514                             Memento (2000)
# 590                      Monsters, Inc. (2001)
#
#                                                Filme 4  \
# 40   Star Wars: Episode V - The Empire Strikes Back...
# 92                    Silence of the Lambs, The (1991)
# 123                                   Toy Story (1995)
# 245                   Silence of the Lambs, The (1991)
# 312                   Silence of the Lambs, The (1991)
# 460                            Schindler's List (1993)
# 514                                   Gladiator (2000)
# 590  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
#
#                                           Filme 5        MSE
# 40                              Fight Club (1999)  23.796117
# 92                              Braveheart (1995)  24.781250
# 123                              Apollo 13 (1995)  25.491071
# 245                             Braveheart (1995)  14.571429
# 312                        American Beauty (1999)  22.914798
# 460                             Braveheart (1995)  27.472561
# 514                    Usual Suspects, The (1995)  19.485516
# 590  Eternal Sunshine of the Spotless Mind (2004)  19.667582
